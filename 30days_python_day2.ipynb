# %% [markdown]
# <a href="https://colab.research.google.com/github/Bappaditya-kuilya/ML_learning/blob/main/30days_python_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Variable

# %%
first_name='Bappaditya'
last_name='Kuilya'
country = 'India'
city = 'Kolkata'
age = 19
is_married = False
skills = ['python','HTML','Java']

personal_info = {
    'firstname':'Bappaditya',
    'lastname':'Kuilya',
    'country':'India',
    'city':'Kolkata'
}

# Printing the values stored in the variables

print('First Name:',first_name)
print('Length of First Name:',len(first_name))
print('Last Name:',last_name)
print('Length of Last Name:',len(last_name))
print('Country:',country)
print('City:',city)
print('Age:',age)
print('Married:',is_married)
print('Skills:',skills)
print('Personal Information:',personal_info)


# Declaring multiple variables in one line

first_name, last_name, country, age, is_married = 'Bappaditya', 'Kuilya', 'India', 19, False

print(first_name,last_name,country,age,is_married)
print('First name:', first_name)
print('Last name: ', last_name)
print('Country: ', country)
print('Age: ', age)
print('Married: ', is_married)
# Out:
# First Name: Bappaditya
# Length of First Name: 10
# Last Name: Kuilya
# Length of Last Name: 6
# Country: India
# City: Kolkata
# Age: 19
# Married: False
# Skills: ['python', 'HTML', 'Java']
# Personal Information: {'firstname': 'Bappaditya', 'lastname': 'Kuilya', 'country': 'India', 'city': 'Kolkata'}
# Bappaditya Kuilya India 19 False
# First name: Bappaditya
# Last name:  Kuilya
# Country:  India
# Age:  19
# Married:  False

# %% [markdown]
# ##Questions
#
# 1. Mid
#
# Create variables for your name, age, country, city, and occupation. Print them in a readable format.
#
# 2. Mid
#
# Create a string containing your full name. Print the full name, its length, and the first and last characters.
#
# 3. Hard
#
# Create variables for a student's name, age, college, CGPA, skills, and contact information. Store the skills in a list and the contact information in a dictionary. Print all the information.
#
# 4. Hard
#
# Create five variables in a single statement. Then exchange their values so that each variable receives the value previously stored in another variable.
#
# 5. Tricky
#
# Create a variable containing your full name and determine the number of characters in the name without counting spaces. Print the result.

# %%
# 1.Create variables for your name, age, country, city, and occupation. Print them in a readable format.

name = "Bappaditya Kuilya"
age = 19
country ="India"
city = "Kolkata"
occupation = "Student"

print("Name :",name)
print("Age :",age)
print("Country :",country)
print("City :",city)
print("Occupation :",occupation)
# Out:
# Name : Bappaditya Kuilya
# Age : 19
# Country : India
# City : Kolkata
# Occupation : Student

# %%
# 2.Create a string containing your full name. Print the full name, its length, and the first and last characters.

full_name = "Bappaditya Kuilya"
print("Full Name :",full_name)
print("Length of Full Name :",len(full_name))
print("First Character :",full_name[0])
print("Last Character :",full_name[-1])

# %%
# 3.Create variables for a student's name, age, college, CGPA, skills, and contact information. Store the skills in a list and the contact information in a dictionary. Print all the information.

name = "Bappaditya Kuilya"
age = 19
college = "UEMK"
CGPA = 8.1
skills = ['Python','Java','LLM']
contact = {
    "Address":"Kolkata",
    "Mobile No.":"9100000000"
}

print("Name :",name)
print("Age :",age)
print("College :",college)
print("CGPA :",CGPA)
print("Skills :",skills)
print("Contact :",contact)
# Out:
# Name : Bappaditya Kuilya
# Age : 19
# College : UEMK
# CGPA : 8.1
# Skills : ['Python', 'Java', 'LLM']
# Contact : {'Address': 'Kolkata', 'Mobile No.': '9100000000'}

# %%
# 4.Create five variables in a single statement. Then exchange their values so that each variable receives the value previously stored in another variable.

a,b,c,d,e = 1,2,3,4,5

print(a,b,c,d,e)

a,b,c,d,e = e,d,c,b,a

print(a,b,c,d,e)
# Out:
# 1 2 3 4 5
# 5 4 3 2 1

# %%
#  5.Create a variable containing your full name and determine the number of characters in the name without counting spaces. Print the result.

full_name = "Bappaditya Kuilya"
print("Full Name :",full_name)
print("Length of Full Name :",len(full_name.replace(" ","")))
# Out:
# Full Name : Bappaditya Kuilya
# Length of Full Name : 16
