# %% [markdown]
# <a href="https://colab.research.google.com/github/Bappaditya-kuilya/ML_learning/blob/main/30_days_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Python_Basics

# %%
print("Hello World!")

print(3+2)
print(3-2)
print(3/2)
print(3*2)
print(3%2)   #modulo
print(3//2)  #floor
print(3**2)  #exponential

print(type(10))
print(type(10.5))
print(type(5j+10))
print(type({10,20,20,30}))
print(type((10,20,30,20)))
print(type([10,20,30,10]))
print(type({"Books": "AI_ML"}))
print(type('Bappa'))
# Out:
# Hello World!
# 5
# 1
# 1.5
# 6
# 1
# 1
# 9
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'set'>
# <class 'tuple'>
# <class 'list'>
# <class 'dict'>
# <class 'str'>

# %% [markdown]
# ### Pushing Files to GitHub (Authorized via Colab)
# Since you've authorized GitHub in Colab settings, you can use the notebook UI to save. If you want to push files via code without manually managing tokens, run this to configure your environment:

# %%
# Replace these with your details
USER_NAME = "Bappaditya-kuilya"
USER_EMAIL = "your_email@example.com"
REPO_NAME = "ML_learning"

# !git config --global user.name "{USER_NAME}"
# !git config --global user.email "{USER_EMAIL}"

# Clone the repo to start working inside it
# !git clone https://github.com/{USER_NAME}/{REPO_NAME}.git
# %cd {REPO_NAME}

# %% [markdown]
# After running the above, you can move your work into that folder and use the 'Save a copy in GitHub' feature under the File menu to update your repository seamlessly.
